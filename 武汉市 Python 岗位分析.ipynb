# %%
import json
import numpy as np
import pandas as pd
from pyecharts import Bar, Pie, Grid, online

online()

# %%
# 读取数据

with open("./joblist180913.json", "r") as f:
    data = json.load(f)

frame = pd.DataFrame(data)
frame = frame.fillna({"industryField": "未知"})
company_frame = frame.drop_duplicates(["companyId"])

# %%
# 岗位需求区域分布

job_district = frame.district.value_counts()
company_district = company_frame.district.value_counts()

bar = Bar("岗位需求区域分布", "武汉市 Python 岗位分析")
bar.add(
    "岗位数量",
    job_district.index,
    job_district.values,
    is_label_show=True,
    xaxis_interval=0,
    xaxis_rotate=30
)
bar.add(
    "企业数量",
    company_district.index,
    company_district.values,
    is_label_show=True,
    xaxis_interval=0,
    xaxis_rotate=30
)

bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="11408ecbce9c421ca9cd40fcf2991b69" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_11408ecbce9c421ca9cd40fcf2991b69 = echarts.init(document.getElementById('11408ecbce9c421ca9cd40fcf2991b69'), 'light', {renderer: 'canvas'});
#
# var option_11408ecbce9c421ca9cd40fcf2991b69 = {
#     "title": [
#         {
#             "text": "\u5c97\u4f4d\u9700\u6c42\u533a\u57df\u5206\u5e03",
#             "subtext": "\u6b66\u6c49\u5e02 Python \u5c97\u4f4d\u5206\u6790",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 8857525,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5c97\u4f4d\u6570\u91cf",
#             "data": [
#                 258.0,
#                 216.0,
#                 74.0,
#                 68.0,
#                 28.0,
#                 15.0,
#                 8.0,
#                 8.0,
#                 5.0,
#                 2.0,
#                 2.0,
#                 1.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 8857525
#         },
#         {
#             "type": "bar",
#             "name": "\u4f01\u4e1a\u6570\u91cf",
#             "data": [
#                 104.0,
#                 73.0,
#                 37.0,
#                 22.0,
#                 18.0,
#                 8.0,
#                 5.0,
#                 4.0,
#                 2.0,
#                 2.0,
#                 2.0,
#                 1.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 8857525
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5c97\u4f4d\u6570\u91cf",
#                 "\u4f01\u4e1a\u6570\u91cf"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": 0,
#                 "rotate": 30,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u6d2a\u5c71\u533a",
#                 "\u4e1c\u6e56\u65b0\u6280\u672f\u5f00\u53d1\u533a",
#                 "\u6b66\u660c\u533a",
#                 "\u6c5f\u590f\u533a",
#                 "\u6c5f\u6c49\u533a",
#                 "\u6c5f\u5cb8\u533a",
#                 "\u785a\u53e3\u533a",
#                 "\u6c49\u9633\u533a",
#                 "\u6b66\u6c49\u7ecf\u6d4e\u6280\u672f\u5f00\u53d1\u533a",
#                 "\u9752\u5c71\u533a",
#                 "\u4e1c\u897f\u6e56\u533a",
#                 "\u9ec4\u9642\u533a"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_11408ecbce9c421ca9cd40fcf2991b69.setOption(option_11408ecbce9c421ca9cd40fcf2991b69);
#
#     });
# </script>

# %%
# 招聘企业规模

bar = Bar("招聘企业规模", "武汉市 Python 岗位分析")
company_size = company_frame.companySize.value_counts()
bar.add("", company_size.index, company_size.values, is_label_show=True)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="5dfabde8c32c4c3e9112abc0feeedadc" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_5dfabde8c32c4c3e9112abc0feeedadc = echarts.init(document.getElementById('5dfabde8c32c4c3e9112abc0feeedadc'), 'light', {renderer: 'canvas'});
#
# var option_5dfabde8c32c4c3e9112abc0feeedadc = {
#     "title": [
#         {
#             "text": "\u62db\u8058\u4f01\u4e1a\u89c4\u6a21",
#             "subtext": "\u6b66\u6c49\u5e02 Python \u5c97\u4f4d\u5206\u6790",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 7798246,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 73.0,
#                 67.0,
#                 57.0,
#                 34.0,
#                 33.0,
#                 15.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 7798246
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "50-150\u4eba",
#                 "15-50\u4eba",
#                 "150-500\u4eba",
#                 "500-2000\u4eba",
#                 "2000\u4eba\u4ee5\u4e0a",
#                 "\u5c11\u4e8e15\u4eba"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_5dfabde8c32c4c3e9112abc0feeedadc.setOption(option_5dfabde8c32c4c3e9112abc0feeedadc);
#
#     });
# </script>

# %%
# 招聘企业融资情况

bar = Bar("招聘企业融资情况", "武汉市 Python 岗位分析")
finance_stage = company_frame.financeStage.value_counts()
bar.add("", finance_stage.index, finance_stage.values, is_label_show=True)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="343d5571533c4dc4a6ef7e961addad02" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_343d5571533c4dc4a6ef7e961addad02 = echarts.init(document.getElementById('343d5571533c4dc4a6ef7e961addad02'), 'light', {renderer: 'canvas'});
#
# var option_343d5571533c4dc4a6ef7e961addad02 = {
#     "title": [
#         {
#             "text": "\u62db\u8058\u4f01\u4e1a\u878d\u8d44\u60c5\u51b5",
#             "subtext": "\u6b66\u6c49\u5e02 Python \u5c97\u4f4d\u5206\u6790",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 8171964,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 70.0,
#                 68.0,
#                 38.0,
#                 34.0,
#                 26.0,
#                 26.0,
#                 9.0,
#                 8.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 8171964
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u672a\u878d\u8d44",
#                 "\u4e0d\u9700\u8981\u878d\u8d44",
#                 "\u4e0a\u5e02\u516c\u53f8",
#                 "A\u8f6e",
#                 "B\u8f6e",
#                 "\u5929\u4f7f\u8f6e",
#                 "D\u8f6e\u53ca\u4ee5\u4e0a",
#                 "C\u8f6e"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_343d5571533c4dc4a6ef7e961addad02.setOption(option_343d5571533c4dc4a6ef7e961addad02);
#
#     });
# </script>

# %%
# 招聘企业行业分布

# 某些企业所属多个行业，只能定性分析
industries = []
for industry in company_frame.industryField.values:
    if "," in industry:
        industries += [i.strip() for i in industry.split(",")]
    elif "、" in industry:
        industries += [i.strip() for i in industry.split("、")]
    else:
        industries += [i.strip() for i in industry.split()]
        
industries = pd.DataFrame({'data': industries})

pie = Pie("招聘企业行业分布", "武汉市 Python 岗位分析", title_pos="center")
data = industries.data.value_counts()
pie.add(
    "",
    data.index,
    data.values,
    is_label_show=True,
    legend_orient="vertical",
    legend_pos="left",
    radius=[25,75],
    center=[60, 55],
    rosetype="area",
)
pie
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="d137dea340b74bfeaabe0650f57b47ce" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_d137dea340b74bfeaabe0650f57b47ce = echarts.init(document.getElementById('d137dea340b74bfeaabe0650f57b47ce'), 'light', {renderer: 'canvas'});
#
# var option_d137dea340b74bfeaabe0650f57b47ce = {
#     "title": [
#         {
#             "text": "\u62db\u8058\u4f01\u4e1a\u884c\u4e1a\u5206\u5e03",
#             "subtext": "\u6b66\u6c49\u5e02 Python \u5c97\u4f4d\u5206\u6790",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 3352911,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "pie",
#             "data": [
#                 {
#                     "name": "\u79fb\u52a8\u4e92\u8054\u7f51",
#                     "value": 166.0
#                 },
#                 {
#                     "name": "\u6570\u636e\u670d\u52a1",
#                     "value": 65.0
#                 },
#                 {
#                     "name": "\u7535\u5b50\u5546\u52a1",
#                     "value": 33.0
#                 },
#                 {
#                     "name": "\u4f01\u4e1a\u670d\u52a1",
#                     "value": 26.0
#                 },
#                 {
#                     "name": "\u6e38\u620f",
#                     "value": 22.0
#                 },
#                 {
#                     "name": "\u4fe1\u606f\u5b89\u5168",
#                     "value": 22.0
#                 },
#                 {
#                     "name": "\u91d1\u878d",
#                     "value": 19.0
#                 },
#                 {
#                     "name": "\u5176\u4ed6",
#                     "value": 18.0
#                 },
#                 {
#                     "name": "O2O",
#                     "value": 15.0
#                 },
#                 {
#                     "name": "\u6559\u80b2",
#                     "value": 11.0
#                 },
#                 {
#                     "name": "\u786c\u4ef6",
#                     "value": 11.0
#                 },
#                 {
#                     "name": "\u6587\u5316\u5a31\u4e50",
#                     "value": 10.0
#                 },
#                 {
#                     "name": "\u533b\u7597\u5065\u5eb7",
#                     "value": 10.0
#                 },
#                 {
#                     "name": "\u793e\u4ea4\u7f51\u7edc",
#                     "value": 8.0
#                 },
#                 {
#                     "name": "\u751f\u6d3b\u670d\u52a1",
#                     "value": 7.0
#                 },
#                 {
#                     "name": "\u5e7f\u544a\u8425\u9500",
#                     "value": 6.0
#                 },
#                 {
#                     "name": "\u4eba\u5de5\u667a\u80fd",
#                     "value": 3.0
#                 },
#                 {
#                     "name": "\u62db\u8058",
#                     "value": 3.0
#                 },
#                 {
#                     "name": "\u672a\u77e5",
#                     "value": 1.0
#                 },
#                 {
#                     "name": "\u533a\u5757\u94fe",
#                     "value": 1.0
#                 }
#             ],
#             "radius": [
#                 "25%",
#                 "75%"
#             ],
#             "center": [
#                 "60%",
#                 "55%"
#             ],
#             "roseType": "area",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 3352911
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u79fb\u52a8\u4e92\u8054\u7f51",
#                 "\u6570\u636e\u670d\u52a1",
#                 "\u7535\u5b50\u5546\u52a1",
#                 "\u4f01\u4e1a\u670d\u52a1",
#                 "\u6e38\u620f",
#                 "\u4fe1\u606f\u5b89\u5168",
#                 "\u91d1\u878d",
#                 "\u5176\u4ed6",
#                 "O2O",
#                 "\u6559\u80b2",
#                 "\u786c\u4ef6",
#                 "\u6587\u5316\u5a31\u4e50",
#                 "\u533b\u7597\u5065\u5eb7",
#                 "\u793e\u4ea4\u7f51\u7edc",
#                 "\u751f\u6d3b\u670d\u52a1",
#                 "\u5e7f\u544a\u8425\u9500",
#                 "\u4eba\u5de5\u667a\u80fd",
#                 "\u62db\u8058",
#                 "\u672a\u77e5",
#                 "\u533a\u5757\u94fe"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "left",
#             "top": "top",
#             "orient": "vertical",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_d137dea340b74bfeaabe0650f57b47ce.setOption(option_d137dea340b74bfeaabe0650f57b47ce);
#
#     });
# </script>

# %%
# 岗位二级分类

bar = Bar("岗位二级分类（数量 >= 5）", "武汉市 Python 岗位分析")
second_type = frame.secondType.value_counts()
second_type = second_type[second_type >= 5]
bar.add("", second_type.index, second_type.values, is_label_show=True, xaxis_interval=0, xaxis_rotate=30)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="34652732de104f9abc922c006d4f86dc" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_34652732de104f9abc922c006d4f86dc = echarts.init(document.getElementById('34652732de104f9abc922c006d4f86dc'), 'light', {renderer: 'canvas'});
#
# var option_34652732de104f9abc922c006d4f86dc = {
#     "title": [
#         {
#             "text": "\u5c97\u4f4d\u4e8c\u7ea7\u5206\u7c7b\uff08\u6570\u91cf >= 5\uff09",
#             "subtext": "\u6b66\u6c49\u5e02 Python \u5c97\u4f4d\u5206\u6790",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 3996944,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 225.0,
#                 113.0,
#                 75.0,
#                 73.0,
#                 61.0,
#                 56.0,
#                 34.0,
#                 11.0,
#                 10.0,
#                 9.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 3996944
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": 0,
#                 "rotate": 30,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u540e\u7aef\u5f00\u53d1",
#                 "\u6d4b\u8bd5",
#                 "\u6570\u636e\u5f00\u53d1",
#                 "\u8fd0\u7ef4",
#                 "\u79fb\u52a8\u524d\u7aef\u5f00\u53d1",
#                 "\u4eba\u5de5\u667a\u80fd",
#                 "\u4f01\u4e1a\u8f6f\u4ef6",
#                 "\u9879\u76ee\u7ba1\u7406",
#                 "\u6570\u636e\u5206\u6790",
#                 "\u9ad8\u7aef\u6280\u672f\u804c\u4f4d"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_34652732de104f9abc922c006d4f86dc.setOption(option_34652732de104f9abc922c006d4f86dc);
#
#     });
# </script>

# %%
# 岗位经验要求

bar = Bar("岗位经验要求", "武汉市 Python 岗位分析")
work_year = frame.workYear.value_counts()
bar.add("", work_year.index, work_year.values, is_label_show=True)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="3cd7bcf4b5b9401cb2d7283acd3d3da3" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_3cd7bcf4b5b9401cb2d7283acd3d3da3 = echarts.init(document.getElementById('3cd7bcf4b5b9401cb2d7283acd3d3da3'), 'light', {renderer: 'canvas'});
#
# var option_3cd7bcf4b5b9401cb2d7283acd3d3da3 = {
#     "title": [
#         {
#             "text": "\u5c97\u4f4d\u7ecf\u9a8c\u8981\u6c42",
#             "subtext": "\u6b66\u6c49\u5e02 Python \u5c97\u4f4d\u5206\u6790",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 8478333,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 305.0,
#                 208.0,
#                 84.0,
#                 52.0,
#                 35.0,
#                 5.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 8478333
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "3-5\u5e74",
#                 "1-3\u5e74",
#                 "\u4e0d\u9650",
#                 "5-10\u5e74",
#                 "\u5e94\u5c4a\u6bd5\u4e1a\u751f",
#                 "1\u5e74\u4ee5\u4e0b"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_3cd7bcf4b5b9401cb2d7283acd3d3da3.setOption(option_3cd7bcf4b5b9401cb2d7283acd3d3da3);
#
#     });
# </script>

# %%
# 岗位学历要求

bar = Bar("岗位学历要求", "武汉市 Python 岗位分析")
education = frame.education.value_counts()
bar.add("", education.index, education.values, is_label_show=True)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="ccd49469aa304e43a40d741ca42aa608" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_ccd49469aa304e43a40d741ca42aa608 = echarts.init(document.getElementById('ccd49469aa304e43a40d741ca42aa608'), 'light', {renderer: 'canvas'});
#
# var option_ccd49469aa304e43a40d741ca42aa608 = {
#     "title": [
#         {
#             "text": "\u5c97\u4f4d\u5b66\u5386\u8981\u6c42",
#             "subtext": "\u6b66\u6c49\u5e02 Python \u5c97\u4f4d\u5206\u6790",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 3559369,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 519.0,
#                 85.0,
#                 49.0,
#                 36.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 3559369
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u672c\u79d1",
#                 "\u5927\u4e13",
#                 "\u7855\u58eb",
#                 "\u4e0d\u9650"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_ccd49469aa304e43a40d741ca42aa608.setOption(option_ccd49469aa304e43a40d741ca42aa608);
#
#     });
# </script>

# %%
# 岗位薪资

bar = Bar("岗位薪资（数量 >= 10）", "武汉市 Python 岗位分析")
salary = frame.salary.value_counts()
salary = salary[salary >= 10]
bar.add("", salary.index, salary.values, is_label_show=True, xaxis_interval=0, xaxis_rotate=30)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="ef816c167a174ef083185f48148d8ffb" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_ef816c167a174ef083185f48148d8ffb = echarts.init(document.getElementById('ef816c167a174ef083185f48148d8ffb'), 'light', {renderer: 'canvas'});
#
# var option_ef816c167a174ef083185f48148d8ffb = {
#     "title": [
#         {
#             "text": "\u5c97\u4f4d\u85aa\u8d44\uff08\u6570\u91cf >= 10\uff09",
#             "subtext": "\u6b66\u6c49\u5e02 Python \u5c97\u4f4d\u5206\u6790",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 7638794,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 87.0,
#                 67.0,
#                 55.0,
#                 45.0,
#                 41.0,
#                 29.0,
#                 29.0,
#                 19.0,
#                 19.0,
#                 17.0,
#                 14.0,
#                 14.0,
#                 13.0,
#                 12.0,
#                 12.0,
#                 11.0,
#                 11.0,
#                 10.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 7638794
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": 0,
#                 "rotate": 30,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "10k-20k",
#                 "15k-30k",
#                 "10k-15k",
#                 "15k-25k",
#                 "8k-15k",
#                 "6k-10k",
#                 "6k-12k",
#                 "8k-12k",
#                 "7k-14k",
#                 "5k-10k",
#                 "10k-18k",
#                 "12k-24k",
#                 "5k-8k",
#                 "8k-16k",
#                 "8k-10k",
#                 "4k-8k",
#                 "20k-40k",
#                 "15k-20k"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_ef816c167a174ef083185f48148d8ffb.setOption(option_ef816c167a174ef083185f48148d8ffb);
#
#     });
# </script>

# %%
# 1-3年经验薪资

bar = Bar("1-3年经验岗位薪资", "武汉市 Python 岗位分析")

salary = frame[frame['workYear']=="1-3年"].salary.value_counts()

salary = salary[salary >= 10]
bar.add("", salary.index, salary.values, is_label_show=True, xaxis_interval=0, xaxis_rotate=30)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="cd22f605b02146509ec7d989c0e84344" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_cd22f605b02146509ec7d989c0e84344 = echarts.init(document.getElementById('cd22f605b02146509ec7d989c0e84344'), 'light', {renderer: 'canvas'});
#
# var option_cd22f605b02146509ec7d989c0e84344 = {
#     "title": [
#         {
#             "text": "1-3\u5e74\u7ecf\u9a8c\u5c97\u4f4d\u85aa\u8d44",
#             "subtext": "\u6b66\u6c49\u5e02 Python \u5c97\u4f4d\u5206\u6790",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 3432774,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 30.0,
#                 19.0,
#                 15.0,
#                 15.0,
#                 13.0,
#                 12.0,
#                 12.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 3432774
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": 0,
#                 "rotate": 30,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "10k-20k",
#                 "6k-10k",
#                 "8k-15k",
#                 "10k-15k",
#                 "5k-8k",
#                 "15k-30k",
#                 "6k-12k"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_cd22f605b02146509ec7d989c0e84344.setOption(option_cd22f605b02146509ec7d989c0e84344);
#
#     });
# </script>

# %%
# 3-5年经验薪资

bar = Bar("3-5年经验岗位薪资", "武汉市 Python 岗位分析")

salary = frame[frame['workYear']=="3-5年"].salary.value_counts()

salary = salary[salary >= 10]
bar.add("", salary.index, salary.values, is_label_show=True, xaxis_interval=0, xaxis_rotate=30)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="20c4eaa59659443caf4c54c35b68f1e5" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_20c4eaa59659443caf4c54c35b68f1e5 = echarts.init(document.getElementById('20c4eaa59659443caf4c54c35b68f1e5'), 'light', {renderer: 'canvas'});
#
# var option_20c4eaa59659443caf4c54c35b68f1e5 = {
#     "title": [
#         {
#             "text": "3-5\u5e74\u7ecf\u9a8c\u5c97\u4f4d\u85aa\u8d44",
#             "subtext": "\u6b66\u6c49\u5e02 Python \u5c97\u4f4d\u5206\u6790",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 3692758,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 45.0,
#                 38.0,
#                 31.0,
#                 29.0,
#                 20.0,
#                 11.0,
#                 10.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 3692758
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": 0,
#                 "rotate": 30,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "15k-30k",
#                 "10k-20k",
#                 "10k-15k",
#                 "15k-25k",
#                 "8k-15k",
#                 "8k-12k",
#                 "10k-18k"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_20c4eaa59659443caf4c54c35b68f1e5.setOption(option_20c4eaa59659443caf4c54c35b68f1e5);
#
#     });
# </script>
